# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
page_link="https://www.amazon.com/Disney-Princess-Fantasy-Nightgown-AURORA/dp/B0B9894RWR/ref=sr_1_50?dib=eyJ2IjoiMSJ9.lzqWgZ7ywmOACONSrARtl7f7pkA6e0Y0xKT8SDa3B5faQmSsWMCj8nntFwwD_YRrObREE2_7nm8-0ebjx0utgq9olR9FEPRFF2IKDydwlI97MkAHd2DVJALjlS3rf8KPLhdq85UlHWDenMtDBH93BtWiThzfWxkuB2i3UUOaWMs-TxYmcU3oe5XqXo8MEquPaA6w_TBCbnQkTo1QH8ygEO9kwh7XIiCr7edC-8anfuLF-pATYirkEqY5MsdBSMljNMUP2FAIlFoTz8G-Re4xOTOXj7CB9hrZbYBtwS7SD08.d1LHBzeG8S2u8JZ2KNz1NBcD_Ia7rkxgFZbRQ5xVM1Q&dib_tag=se&qid=1715252494&s=fashion-girls-intl-ship&sr=1-50"

respond=requests.get(page_link)

#respond.status_code

html_content=respond.text

soup = bs(html_content, 'html.parser')

soup2 = bs(soup.prettify(), 'html.parser')

print(soup2)

# %%
title = soup2.find(id='productTitle').get_text()
price=soup2.find('span',{'class':'a-price-whole'}).get_text()

title=title.strip()
print(title)

price=price.strip()
print(price)
# Out:
# Disney Girls' Princess Fantasy Gown Nightgown, AURORA, 4T
# 21
#
#                         .

# %%
import datetime

today=datetime.date.today()

print(today)
# Out:
# 2024-05-09

# %%
import csv

header = ['Title', 'Price', 'Date']
data = [title, price,today]

with open('AmazonWebScraper.csv', 'w', newline='', encoding='UTF-8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
import pandas as pd

df=pd.read_csv('/content/AmazonWebScraper.csv')

df

# %%
#Appending the data
with open('AmazonWebScraper.csv', 'a+', newline='', encoding='UTF-8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
def check_price():
  from bs4 import BeautifulSoup as bs
  import requests

  page_link="https://www.amazon.com/Disney-Princess-Fantasy-Nightgown-AURORA/dp/B0B9894RWR/ref=sr_1_50?dib=eyJ2IjoiMSJ9.lzqWgZ7ywmOACONSrARtl7f7pkA6e0Y0xKT8SDa3B5faQmSsWMCj8nntFwwD_YRrObREE2_7nm8-0ebjx0utgq9olR9FEPRFF2IKDydwlI97MkAHd2DVJALjlS3rf8KPLhdq85UlHWDenMtDBH93BtWiThzfWxkuB2i3UUOaWMs-TxYmcU3oe5XqXo8MEquPaA6w_TBCbnQkTo1QH8ygEO9kwh7XIiCr7edC-8anfuLF-pATYirkEqY5MsdBSMljNMUP2FAIlFoTz8G-Re4xOTOXj7CB9hrZbYBtwS7SD08.d1LHBzeG8S2u8JZ2KNz1NBcD_Ia7rkxgFZbRQ5xVM1Q&dib_tag=se&qid=1715252494&s=fashion-girls-intl-ship&sr=1-50"

  respond=requests.get(page_link)

  #respond.status_code

  html_content=respond.text

  soup = bs(html_content, 'html.parser')

  soup2 = bs(soup.prettify(), 'html.parser')

  title = soup2.find(id='productTitle').get_text()
  price=soup2.find('span',{'class':'a-price-whole'}).get_text()

  title=title.strip()

  price=price.strip()

  import datetime

  today=datetime.date.today()

  import csv

  header = ['Title', 'Price', 'Date']
  data = [title, price,today]

  #Appending the data
  with open('AmazonWebScraper.csv', 'a+', newline='', encoding='UTF-8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
import time

while(True):
  check_price()
  time.sleep(86400)

# %%
import pandas as pd

df=pd.read_csv('/content/AmazonWebScraper.csv')

df
# Out:
#                                                Title  \
# 0  Disney Girls' Princess Fantasy Gown Nightgown,...
# 1  Disney Girls' Princess Fantasy Gown Nightgown,...
# 2  Disney Girls' Princess Fantasy Gown Nightgown,...
# 3  Disney Girls' Princess Fantasy Gown Nightgown,...
# 4  Disney Girls' Princess Fantasy Gown Nightgown,...
# 5  Disney Girls' Princess Fantasy Gown Nightgown,...
# 6  Disney Girls' Princess Fantasy Gown Nightgown,...
#
#                                                Price        Date
# 0  21\n                       \n                 ...  2024-05-09
# 1  21\n                       \n                 ...  2024-05-09
# 2  21\n                       \n                 ...  2024-05-09
# 3  21\n                       \n                 ...  2024-05-09
# 4  21\n                       \n                 ...  2024-05-09
# 5  21\n                       \n                 ...  2024-05-09
# 6  21\n                       \n                 ...  2024-05-09
